# %% [markdown]
# # EDA(EXPLORATORY DATA ANALYSIS)

# %% [markdown]
# ## This generally entails exploration of data
# #### -Relationships
# #### -variables
# #### -Distribution
# #### -observations
# #### -missing values
# #### -Outliers
# #### -general summary
# #### -data types
# #### N/B EDA is generrally data cleaning/data wrangling

# %% [markdown]
# <!-- Line graghs are used to plot continous numerical variables both x and y
# bar plots/graphs/count plot-counts
# scatter plots -->b

# %% [markdown]
# #### Loading Packages Needed

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as pyp
import seaborn as sns

# %% [markdown]
# #### Importing the Melbourne dataset

# %%
mb_housing_data=pd.read_csv("C:/Users/Bachelor_001/OneDrive/Desktop/PD/Melbourne_Housing.csv")

# %%
mb_housing_data.head()
# Out:
#          Suburb  Rooms Type        SellerG        Date  Distance  Postcode  \
# 0  Airport West      3    t         Nelson  03-09-2016      13.5    3042.0
# 1   Albert Park      2    h  hockingstuart  03-09-2016       3.3    3206.0
# 2   Albert Park      2    h        Thomson  03-09-2016       3.3    3206.0
# 3    Alphington      4    h          Brace  03-09-2016       6.4    3078.0
# 4    Alphington      3    h         Jellis  03-09-2016       6.4    3078.0
#
#    Bedroom  Bathroom  Car  Landsize BuildingArea  YearBuilt  \
# 0      3.0       2.0  1.0     303.0          225     2016.0
# 1      2.0       1.0  0.0     120.0           82     1900.0
# 2      2.0       1.0  0.0     159.0          inf        NaN
# 3      3.0       2.0  4.0     853.0          263     1930.0
# 4      3.0       2.0  2.0     208.0          inf     2013.0
#
#               Regionname  Propertycount    Price
# 0   Western Metropolitan           3464   840000
# 1  Southern Metropolitan           3280  1275000
# ...

# %% [markdown]
# Loking at mb_housing_data information

# %%
mb_housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27114 entries, 0 to 27113
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27114 non-null  object
#  1   Rooms          27114 non-null  int64
#  2   Type           27114 non-null  object
#  3   SellerG        27114 non-null  object
#  4   Date           27114 non-null  object
#  5   Distance       27113 non-null  float64
#  6   Postcode       27113 non-null  float64
#  7   Bedroom        20678 non-null  float64
#  8   Bathroom       20672 non-null  float64
#  9   Car            20297 non-null  float64
#  10  Landsize       17873 non-null  float64
#  11  BuildingArea   10543 non-null  object
#  12  YearBuilt      11985 non-null  float64
#  13  Regionname     27114 non-null  object
#  14  Propertycount  27114 non-null  int64
#  15  Price          27114 non-null  int64
# dtypes: float64(7), int64(3), object(6)
# memory usage: 3.3+ MB

# %% [markdown]
# <!-- EDAs main goal is to encourage data analysis before making assumptions.
# It can assist in finding glaring errors,understanding data patterns,spotting outliers
# or un ussual occurances and intriguing relationships between variables -->

# %%
mb_housing_data.keys()
# Out:
# Index(['Suburb', 'Rooms', 'Type', 'SellerG', 'Date', 'Distance', 'Postcode',
#        'Bedroom', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt',
#        'Regionname', 'Propertycount', 'Price'],
#       dtype='object')

# %% [markdown]
# ### DATA DESCRIPTION

# %% [markdown]
# * The detailed data dictionary is given below:
# * Suburb-Suburb in which the property is located
# * Rooms-numbers of rooms in the property
# * Type-type of the property like :
#     - h-house,cottage,villa,semi,terrace
#     - t-townhouse,duplex,unit
# * SellerG-name of the real estate agent who sold the agency
# * Date-date on which the property was sold
# * Distance-distance of the property from CBD in kilometers
# * postcode-postcode of the area
# * Bedroom-number of bedrooms in the property
# * Bathroom-number of bathrooms in the property
# * Car-number of car parking spaces in the property
# * Landsize-size of the land in square meters
# * BuildingArea-size of the building in square meters
# * YearBuilt-year in which the building was built
# * Regionname-name of the region in which the propery is located
# * Propertycount-number of properties that are present
# * Price-the price of the property

# %%
mb_housing_data.shape
# Out:
# (27114, 16)

# %% [markdown]
# mb_housing_data has 27114 rows and 16 columns

# %% [markdown]
# #### Getting the number of rows

# %%
mb_housing_data.shape[0]
# Out:
# 27114

# %% [markdown]
# #### Getting the number of columns

# %%
mb_housing_data.shape[1]
# Out:
# 16

# %% [markdown]
# ### Relationships between numerical variables

# %%
numerical_var= mb_housing_data.select_dtypes(include=np.number)
numerical_var.head(2)
# Out:
#    Rooms  Distance  Postcode  Bedroom  Bathroom  Car  Landsize  YearBuilt  \
# 0      3      13.5    3042.0      3.0       2.0  1.0     303.0     2016.0
# 1      2       3.3    3206.0      2.0       1.0  0.0     120.0     1900.0
#
#    Propertycount    Price
# 0           3464   840000
# 1           3280  1275000

# %%
mb_housing_data.keys()
# Out:
# Index(['Suburb', 'Rooms', 'Type', 'SellerG', 'Date', 'Distance', 'Postcode',
#        'Bedroom', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt',
#        'Regionname', 'Propertycount', 'Price'],
#       dtype='object')

# %%
numerical_var.corr()
# Out:
#                   Rooms  Distance  Postcode   Bedroom  Bathroom       Car  \
# Rooms          1.000000  0.284462  0.081110  0.958584  0.608516  0.394298
# Distance       0.284462  1.000000  0.490173  0.282802  0.140484  0.244562
# Postcode       0.081110  0.490173  1.000000  0.087373  0.123812  0.062646
# Bedroom        0.958584  0.282802  0.087373  1.000000  0.605910  0.395814
# Bathroom       0.608516  0.140484  0.123812  0.605910  1.000000  0.306358
# Car            0.394298  0.244562  0.062646  0.395814  0.306358  1.000000
# Landsize       0.071494  0.118486  0.076461  0.071124  0.055461  0.091536
# YearBuilt     -0.003780  0.320887  0.100183  0.006388  0.186618  0.133013
# Propertycount -0.079686 -0.021223  0.024394 -0.059713 -0.040498 -0.013524
# Price          0.465236 -0.210957  0.045061  0.430031  0.430852  0.201333
#
#                Landsize  YearBuilt  Propertycount     Price
# Rooms          0.071494  -0.003780      -0.079686  0.465236
# ...

# %%
mb_housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27114 entries, 0 to 27113
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27114 non-null  object
#  1   Rooms          27114 non-null  int64
#  2   Type           27114 non-null  object
#  3   SellerG        27114 non-null  object
#  4   Date           27114 non-null  object
#  5   Distance       27113 non-null  float64
#  6   Postcode       27113 non-null  float64
#  7   Bedroom        20678 non-null  float64
#  8   Bathroom       20672 non-null  float64
#  9   Car            20297 non-null  float64
#  10  Landsize       17873 non-null  float64
#  11  BuildingArea   10543 non-null  object
#  12  YearBuilt      11985 non-null  float64
#  13  Regionname     27114 non-null  object
#  14  Propertycount  27114 non-null  int64
#  15  Price          27114 non-null  int64
# dtypes: float64(7), int64(3), object(6)
# memory usage: 3.3+ MB

# %% [markdown]
# The following variables should be converted to their c orrrect data types:
# * Date ---datetime
# * Buildingarea---
# * Postacode--

# %%
mb_housing_data.head(5)
# Out:
#          Suburb  Rooms Type        SellerG        Date  Distance  Postcode  \
# 0  Airport West      3    t         Nelson  03-09-2016      13.5    3042.0
# 1   Albert Park      2    h  hockingstuart  03-09-2016       3.3    3206.0
# 2   Albert Park      2    h        Thomson  03-09-2016       3.3    3206.0
# 3    Alphington      4    h          Brace  03-09-2016       6.4    3078.0
# 4    Alphington      3    h         Jellis  03-09-2016       6.4    3078.0
#
#    Bedroom  Bathroom  Car  Landsize BuildingArea  YearBuilt  \
# 0      3.0       2.0  1.0     303.0          225     2016.0
# 1      2.0       1.0  0.0     120.0           82     1900.0
# 2      2.0       1.0  0.0     159.0          inf        NaN
# 3      3.0       2.0  4.0     853.0          263     1930.0
# 4      3.0       2.0  2.0     208.0          inf     2013.0
#
#               Regionname  Propertycount    Price
# 0   Western Metropolitan           3464   840000
# 1  Southern Metropolitan           3280  1275000
# ...

# %%
mb_housing_data.tail()
# Out:
#                  Suburb  Rooms Type    SellerG        Date  Distance  \
# 27109        Noble Park      3    h        C21  30-09-2017      22.7
# 27110         Reservoir      3    u         RW  30-09-2017      12.0
# 27111     Roxburgh Park      4    h      Raine  30-09-2017      20.6
# 27112  Springvale South      3    h  Harcourts  30-09-2017      22.2
# 27113       Westmeadows      4    h      Barry  30-09-2017      16.5
#
#        Postcode  Bedroom  Bathroom  Car  Landsize BuildingArea  YearBuilt  \
# 27109    3174.0      3.0       1.0  6.0     569.0          130     1959.0
# 27110    3073.0      3.0       1.0  1.0       NaN          105     1990.0
# 27111    3064.0      4.0       2.0  2.0       NaN          225     1995.0
# 27112    3172.0      3.0       2.0  1.0     544.0          NaN        NaN
# 27113    3049.0      4.0       2.0  6.0     813.0          140     1960.0
#
#                        Regionname  Propertycount   Price
# ...

# %% [markdown]
# #### Converting Date to the correct dtype

# %%
mb_housing_data["Date"]=pd.to_datetime(mb_housing_data["Date"], dayfirst=True)
mb_housing_data['Date'].head()
# Out:
# 0   2016-09-03
# 1   2016-09-03
# 2   2016-09-03
# 3   2016-09-03
# 4   2016-09-03
# Name: Date, dtype: datetime64[ns]

# %% [markdown]
# #### Converting the Yearbuilt

# %%
# Number of unique elements
mb_housing_data['YearBuilt'].nunique()
# Out:
# 147

# %%
# mb_housing_data['YearBuilt']=mb_housing_data['YearBuilt'].astype()

# %% [markdown]
# #### Converting Postcode

# %%
mb_housing_data['Postcode']=mb_housing_data['Postcode'].astype('object')
mb_housing_data['Postcode'].nunique()
mb_housing_data['Postcode'].unique()
mb_housing_data['Postcode'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 27114 entries, 0 to 27113
# Series name: Postcode
# Non-Null Count  Dtype
# --------------  -----
# 27113 non-null  object
# dtypes: object(1)
# memory usage: 212.0+ KB

# %% [markdown]
# #### Converting Bedroom

# %%
mb_housing_data['Bedroom'].nunique()
mb_housing_data['Bedroom'].unique()
# Out:
# array([ 3.,  2.,  5., nan,  4.,  1.,  6.,  7.,  0., 20.,  8.,  9., 12.,
#        10., 16.])

# %% [markdown]
# #### Converting Bathroom

# %%
mb_housing_data['Bathroom'].nunique()
mb_housing_data['Bathroom'].unique()
# Out:
# array([ 2.,  1.,  3., nan,  4.,  0.,  5.,  7.,  8.,  6.,  9.])

# %% [markdown]
# #### Converting Cars

# %%
mb_housing_data['Car'].unique()
# Out:
# array([ 1.,  0.,  4.,  2.,  6., nan,  3.,  7.,  5.,  9.,  8., 10., 11.,
#        18.])

# %%
#### Converting Buildingarea

# %%
mb_housing_data['BuildingArea'].nunique()
mb_housing_data['BuildingArea'].unique()
# mb_housing_data.loc[mb_housing_data['BuildingArea']=='inf']
# Out:
# array(['225', '82', 'inf', '263', '242', '251', '117', 'missing', '76',
#        '399', '118', '103', '180', '123', '218', '129', '167', '154',
#        '275', '121', nan, '125', '255', '75', '156', '240', '268', '108',
#        '69', '140', '214', '253', '189', '215', '96', '104', '100', '313',
#        '144', '93', '110', '70', '122', '51', '147', '113', '83', '56',
#        '137', '85', '64', '175', '3558', '170', '265', '353', '138', '19',
#        '116', '87', '74', '320', '300', '210', '120', '86', '97', '200',
#        '106', '14', '161', '128', '185', '146', '133', '115', '143',
#        '150', '195', '236', '276', '188', '179', '249', '141', '34', '73',
#        '107', '84', '81', '207', '50', '264', '312', '235', '221', '183',
#        '132', '160', '186', '78', '105', '145', '62', '220', '315', '181',
#        '61', '112', '420', '226', '266', '410', '449', '356', '477',
#        '250', '95', '190', '284', '247', '213', '209', '119', '111',
# ...

# %%
mb_housing_data['BuildingArea']=mb_housing_data['BuildingArea'].replace(['inf','missing','nan'],np.nan)

# %%
mb_housing_data['BuildingArea']=mb_housing_data['BuildingArea'].astype('float')
mb_housing_data['BuildingArea'].dtype
# Out:
# dtype('float64')

# %%
mb_housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27114 entries, 0 to 27113
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27114 non-null  object
#  1   Rooms          27114 non-null  int64
#  2   Type           27114 non-null  object
#  3   SellerG        27114 non-null  object
#  4   Date           27114 non-null  datetime64[ns]
#  5   Distance       27113 non-null  float64
#  6   Postcode       27113 non-null  object
#  7   Bedroom        20678 non-null  float64
#  8   Bathroom       20672 non-null  float64
#  9   Car            20297 non-null  float64
#  10  Landsize       17873 non-null  float64
#  11  BuildingArea   10529 non-null  float64
#  12  YearBuilt      11985 non-null  float64
#  13  Regionname     27114 non-null  object
#  14  Propertycount  27114 non-null  int64
#  15  Price          27114 non-null  int64
# dtypes: datetime64[ns](1), float64(7), int64(3), object(5)
# ...

# %% [markdown]
# ### Summary ststistics
# #### Categorical

# %%
categorical_vars=["Suburb","Type","SellerG","Regionname"]
for Column in categorical_vars:
    print(mb_housing_data[Column].value_counts(normalize=True))
    print( '-'*50)
# Out:
# Suburb
# Reservoir         0.026702
# Bentleigh East    0.018182
# Richmond          0.016117
# Preston           0.015121
# Brunswick         0.014126
#                     ...
# Wandin North      0.000037
# Ferny Creek       0.000037
# Tecoma            0.000037
# Montrose          0.000037
# viewbank          0.000037
# Name: proportion, Length: 345, dtype: float64
# --------------------------------------------------
# Type
# h    0.678506
# u    0.217083
# t    0.104411
# Name: proportion, dtype: float64
# --------------------------------------------------
# SellerG
# Nelson           0.100797
# Jellis           0.092830
# Barry            0.087999
# hockingstuart    0.077303
# Ray              0.058051
#                    ...
# Allan            0.000037
# Jim              0.000037
# iProperty        0.000037
# Batty            0.000037
# Icon             0.000037
# Name: proportion, Length: 347, dtype: float64
# --------------------------------------------------
# Regionname
# ...

# %% [markdown]
# #### Summary statistics

# %% [markdown]
# - there is a huge percentage living in Southern Metropolitan
# - many people prefer type h houses which is covered by 67.78%
# - Nelson,jellies and Barry are the best property sellers
# - Many properties are located in (suburbs) in reserves
# - a smallest percentage are located in westerN...

# %%
mb_housing_data.columns
# Out:
# Index(['Suburb', 'Rooms', 'Type', 'SellerG', 'Date', 'Distance', 'Postcode',
#        'Bedroom', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt',
#        'Regionname', 'Propertycount', 'Price'],
#       dtype='object')

# %%
##mb_housing_data[["Suburb","Type","SellerG","Regionname"]].value_counts(

# %% [markdown]
# #### Missing Values

# %% [markdown]
# A Missing value is an empty entitywhich maybe as a result of blank entry or missing info which is normally denoted by NaN,None,NA,999,-999,9999,0000
# - we will later determine the best technique for handling the missing value after studying the distribution and relationship among the variables in the data
# - For categorical variables we will strongly prefer KNN approach(classifier) as for the numeric we prefer the point above()

# %%
mb_housing_data.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom           6436
# Bathroom          6442
# Car               6817
# Landsize          9241
# BuildingArea     16585
# YearBuilt        15129
# Regionname           0
# Propertycount        0
# Price                0
# dtype: int64

# %% [markdown]
# #### **Eight columns have missing values with the following number of missing values;**
#
# ---
#
# * Distance             1
# * Postcode             1
# * Bedroom           6436
# * Bathroom          6442
# * Car               6817
# * Landsize          9241
# * BuildingArea     16585
# * YearBuilt        15129
#
# Building area has the most missing values,followed by yearbuilt,then landsize...

# %% [markdown]
# #### Finding Duplicates

# %%
mb_housing_data[mb_housing_data.duplicated()]
# Out:
#                Suburb  Rooms Type     SellerG       Date  Distance Postcode  \
# 167           Niddrie      3    h        Brad 2016-09-03      11.2   3042.0
# 7272          Niddrie      3    h       Barry 2017-12-09      10.4   3042.0
# 7399         St Kilda      1    u      Wilson 2017-12-09       5.0   3182.0
# 8496          Mentone      3    t      Buxton 2017-08-12      20.0   3194.0
# 9944     Surrey Hills      2    t      Jellis 2018-01-06      10.2   3127.0
# 12006       Thornbury      3    h     McGrath 2017-07-15       7.0   3071.0
# 12571  Port Melbourne      2    u          RT 2016-04-16       3.8   3207.0
# 14870    Moonee Ponds      2    t    McDonald 2017-06-17       6.2   3039.0
# 15788         Burwood      4    t      Philip 2016-06-18      11.7   3125.0
# 20303     Collingwood      2    u  Alexkarbon 2018-02-24       2.0   3066.0
# 21417      Kensington      1    u      Edward 2016-09-24       4.2   3031.0
#
# ...

# %%
mb_housing_data[mb_housing_data.duplicated()]
mb_housing_data.drop_duplicates(inplace=True)
mb_housing_data.reset_index(drop=True,inplace=True)

# %%
mb_housing_data[mb_housing_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Suburb, Rooms, Type, SellerG, Date, Distance, Postcode, Bedroom, Bathroom, Car, Landsize, BuildingArea, YearBuilt, Regionname, Propertycount, Price]
# Index: []

# %% [markdown]
# #### Summary Statistics

# %%
mb_housing_data.describe().T
# Out:
#                  count                           mean                  min  \
# Rooms          27103.0                       2.992473                  1.0
# Date             27103  2017-05-23 12:25:09.441759488  2016-01-28 00:00:00
# Distance       27102.0                      11.279931                  0.0
# Bedroom        20678.0                       3.046184                  0.0
# Bathroom       20672.0                       1.591525                  0.0
# Car            20297.0                        1.71582                  0.0
# Landsize       17873.0                     560.536564                 50.0
# BuildingArea   10529.0                     154.511857                 11.0
# YearBuilt      11985.0                    1966.618273               1850.0
# Propertycount  27103.0                    7564.741025                 83.0
# Price          27103.0                 1050664.131129              85000.0
#
# ...

# %% [markdown]
# **`Price`**
# - Price has the largest mean
# - the smallest building area is 11 with the largest having 6791
# - the  most expensive property is worth 11200000  with the cheapest being worth 85000

# %% [markdown]
# **`Rooms`**
# - 0n average there are 3 rooms
# - One house has a maximum of 16 rooms and 1191 houses has a minimum of 1 room
# - 75% of the properties have 4 rooms
# - Mean and medium are approximately the same (Hence expecting a normal )

# %% [markdown]
# **`Distance`**
# -  On average we have a property 11.28km away from CBD
# -  The furthest 5 properties from the CBD are 48.1 km away with the closest 58 properties  in  the CBD
# -  75% of the properties are 14.0 km away from the CBD

# %% [markdown]
# #### properties having 16 rooms

# %%
mb_housing_data[mb_housing_data['Rooms']==16]
# Out:
#         Suburb  Rooms Type SellerG       Date  Distance Postcode  Bedroom  \
# 25916  Mitcham     16    h  Buxton 2017-10-28      17.2   3132.0     16.0
#
#        Bathroom  Car  Landsize  BuildingArea  YearBuilt            Regionname  \
# 25916       8.0  8.0       NaN           NaN        NaN  Eastern Metropolitan
#
#        Propertycount    Price
# 25916           6871  5000000

# %%
len(mb_housing_data[mb_housing_data['Rooms']==1])
# Out:
# 1191

# %%
len(mb_housing_data[mb_housing_data['Distance']==0.0])
# Out:
# 58

# %%
len(mb_housing_data[mb_housing_data['Distance']==48.1])
# Out:
# 5

# %%
len(mb_housing_data[mb_housing_data['Distance']==14.0])
# Out:
# 319

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
Numerical_variables=mb_housing_data.select_dtypes("number")
print(Numerical_variables)
# Out:
#        Rooms  Distance  Bedroom  Bathroom  Car  Landsize  BuildingArea  \
# 0          3      13.5      3.0       2.0  1.0     303.0         225.0
# 1          2       3.3      2.0       1.0  0.0     120.0          82.0
# 2          2       3.3      2.0       1.0  0.0     159.0           NaN
# 3          4       6.4      3.0       2.0  4.0     853.0         263.0
# 4          3       6.4      3.0       2.0  2.0     208.0           NaN
# ...      ...       ...      ...       ...  ...       ...           ...
# 27098      3      22.7      3.0       1.0  6.0     569.0         130.0
# 27099      3      12.0      3.0       1.0  1.0       NaN         105.0
# 27100      4      20.6      4.0       2.0  2.0       NaN         225.0
# 27101      3      22.2      3.0       2.0  1.0     544.0           NaN
# 27102      4      16.5      4.0       2.0  6.0     813.0         140.0
#
#        YearBuilt  Propertycount    Price
# 0         2016.0           3464   840000
# ...

# %%
Numerical_variables.keys()
# Out:
# Index(['Rooms', 'Distance', 'Bedroom', 'Bathroom', 'Car', 'Landsize',
#        'BuildingArea', 'YearBuilt', 'Propertycount', 'Price'],
#       dtype='object')

# %% [markdown]
# #### Rooms

# %%
sns.histplot(x=Numerical_variables['Rooms'],
             stat="density")
pyp.show()
sns.boxplot(x=Numerical_variables['Rooms'])
pyp.show()
sns.displot(x=Numerical_variables['Rooms'],kind="kde")
pyp.show()

# %% [markdown]
# **`Rooms`**
# - A multi modal distribution
# - most properties have have an average of 2 rooms
# - The maximum number of rooms in a property is 7 while the mininmum number of rooms in a property is 1

# %%
mb_housing_data[mb_housing_data['Rooms']==16]
# Out:
#         Suburb  Rooms Type SellerG       Date  Distance Postcode  Bedroom  \
# 25916  Mitcham     16    h  Buxton 2017-10-28      17.2   3132.0     16.0
#
#        Bathroom  Car  Landsize  BuildingArea  YearBuilt            Regionname  \
# 25916       8.0  8.0       NaN           NaN        NaN  Eastern Metropolitan
#
#        Propertycount    Price
# 25916           6871  5000000

# %%
mb_housing_data.loc[(mb_housing_data['Rooms']==3), 'Regionname'].value_counts()
# Out:
# Regionname
# Northern Metropolitan         3503
# Western Metropolitan          3015
# Southern Metropolitan         2996
# Eastern Metropolitan          1471
# South-Eastern Metropolitan     686
# Northern Victoria               89
# Eastern Victoria                79
# Western Victoria                62
# Name: count, dtype: int64

# %%
mb_housing_data.loc[(mb_housing_data['Rooms']==8), 'Regionname'].value_counts()
# Out:
# Regionname
# Southern Metropolitan    5
# Northern Metropolitan    4
# Eastern Metropolitan     2
# Western Metropolitan     2
# Eastern Victoria         1
# Name: count, dtype: int64

# %% [markdown]
# #### Distance

# %%
sns.histplot(x=Numerical_variables['Distance'],stat="density")
pyp.show()
sns.boxplot(x=Numerical_variables['Distance'])
pyp.show()
sns.displot(x=Numerical_variables['Distance'],kind="kde")

# %% [markdown]
# **`Distance`**
#  - is skewed to the right(positively skewed distribution)
#  - 25 km is the average distance of properties from the CBD
#  - The furthest properties (ie Which are 5) are 48.1 km away from the CBD
#  - The minimum distance from the CBD is zero(58 properties are located inside the CBD)
#  - 25896 properties are located <=25 km away from the CBD this implies that most properties are located with a maximum of 25 km away from the CBD. With 1206 properties located past 25 km away from the CBD

# %%
mb_housing_data[mb_housing_data['Distance']==48.1]
# Out:
#              Suburb  Rooms Type SellerG       Date  Distance Postcode  \
# 4353   New Gisborne      4    h   Raine 2017-09-03      48.1   3438.0
# 9806   New Gisborne      3    h   Raine 2018-01-06      48.1   3438.0
# 16490  New Gisborne      4    h   Raine 2017-11-18      48.1   3438.0
# 19905  New Gisborne      5    h   Raine 2017-09-23      48.1   3438.0
# 19906  New Gisborne      3    h   Raine 2017-09-23      48.1   3438.0
#
#        Bedroom  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# 4353       4.0       2.0  2.0       NaN         175.0     2002.0
# 9806       3.0       2.0  2.0     850.0           NaN        NaN
# 16490      NaN       NaN  NaN       NaN           NaN        NaN
# 19905      5.0       3.0  5.0    4450.0         445.0        NaN
# 19906      3.0       1.0  2.0       NaN           NaN        NaN
#
#               Regionname  Propertycount    Price
# 4353   Northern Victoria            849   690000
# 9806   Northern Victoria            849   625000
# ...

# %%
# Number of buildings at Distance==0
len(mb_housing_data[mb_housing_data['Distance']==48.1])
# Out:
# 5

# %%
# Number of buildings at Distance==0
len(mb_housing_data[mb_housing_data['Distance']==0])
# Out:
# 58

# %%
# number of properties <25km
len(mb_housing_data[mb_housing_data['Distance']<=25])
# Out:
# 25896

# %%
# number of properties >25km
len(mb_housing_data[mb_housing_data['Distance']>25])
# Out:
# 1206

# %% [markdown]
# #### Bedroom

# %%
sns.histplot(x=Numerical_variables['Bedroom'],stat="density")
pyp.show()
sns.boxplot(x=Numerical_variables['Bedroom'])
pyp.show()
sns.displot(x=Numerical_variables['Bedroom'],kind="kde")
pyp.show()

# %% [markdown]
# **`Bedroom`**
# - Bedroom is having a Multi modal distribution
# - Properties have an average of 3 rooms
# - We have one property with 16 rooms being the property with the most bedrooms
# - There are 16 properties with no bedrooms
# - Properties have a maximum of 8 rooms and a minimum of 0 bedrooms

# %%
mb_housing_data['Bedroom'].value_counts()
# Out:
# Bedroom
# 3.0     9365
# 4.0     4738
# 2.0     4660
# 5.0      974
# 1.0      778
# 6.0      109
# 7.0       19
# 0.0       16
# 8.0        9
# 10.0       4
# 9.0        3
# 20.0       1
# 12.0       1
# 16.0       1
# Name: count, dtype: int64

# %% [markdown]
# #### Bathroom

# %%
sns.histplot(x=Numerical_variables["Bathroom"],stat="density")
pyp.show()
sns.boxplot(x=Numerical_variables["Bathroom"])
pyp.show()
sns.displot(x=Numerical_variables["Bathroom"],kind="kde")

# %% [markdown]
# **`Bathroom`**

# %% [markdown]
# #### Car

# %% [markdown]
# #### Landsize

# %% [markdown]
# #### BuildingArea

# %% [markdown]
# #### YearBuilt

# %% [markdown]
# #### Propertycount

# %% [markdown]
# #### Price

# %% [markdown]
# #### MULTIVARIATE ANALYSIS

# %%
Numerical_variables.corr()
# Out:
#                   Rooms  Distance   Bedroom  Bathroom       Car  Landsize  \
# Rooms          1.000000  0.284292  0.958584  0.608516  0.394298  0.071494
# Distance       0.284292  1.000000  0.282802  0.140484  0.244562  0.118486
# Bedroom        0.958584  0.282802  1.000000  0.605910  0.395814  0.071124
# Bathroom       0.608516  0.140484  0.605910  1.000000  0.306358  0.055461
# Car            0.394298  0.244562  0.395814  0.306358  1.000000  0.091536
# Landsize       0.071494  0.118486  0.071124  0.055461  0.091536  1.000000
# BuildingArea   0.418217  0.101988  0.412782  0.388836  0.217719  0.058050
# YearBuilt     -0.003780  0.320887  0.006388  0.186618  0.133013  0.044968
# Propertycount -0.079686 -0.021224 -0.059713 -0.040498 -0.013524 -0.020294
# Price          0.465160 -0.211194  0.430031  0.430852  0.201333  0.042792
#
#                BuildingArea  YearBuilt  Propertycount     Price
# Rooms              0.418217  -0.003780      -0.079686  0.465160
# ...

# %% [markdown]
# **`Rooms`**
#  - There is a very weak positive relationship between Rooms and Distance
#  - There is a strong positive relatinship between Rooms and Bedroom
#  - There is a strong positive relatinship between Rooms and Bathroom

# %% [markdown]
# #### Plotting a heatmap to observe stregths of the correllations

# %%
sns.heatmap(Numerical_variables.corr(),annot=True,cmap="Spectral",vmin=-1,vmax=1)
# Out:
# <Axes: >

# %% [markdown]
# #### plotting a pairplot

# %%
sns.pairplot(Numerical_variables)
pyp.show()

# %%
mb_housing_data.keys()
# Out:
# Index(['Suburb', 'Rooms', 'Type', 'SellerG', 'Date', 'Distance', 'Postcode',
#        'Bedroom', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt',
#        'Regionname', 'Propertycount', 'Price'],
#       dtype='object')

# %% [markdown]
# #### Distribution of Prices by Type

# %%
# sns.displot(x=Numerical_variables['Price'],kind="kde",hue="Numerical_variables["Type"]")

# %%
sns.displot(data=mb_housing_data,x="Price",hue="Type")
pyp.show()
sns.histplot(data=mb_housing_data,x="Price",hue="Type")
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
s

# %%
mb_housing_data['Type'].nunique()
# Out:
# 3

# %%
mb_housing_data['Type'].unique()
# Out:
# array(['t', 'h', 'u'], dtype=object)
